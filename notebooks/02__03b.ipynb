# %% [markdown]
# ## Data Filtering and Selection

# %%
# !pip install --upgrade pip 
# !pip install pandas
# Out:
# ...
#   Using cached pip-26.0.1-py3-none-any.whl.metadata (4.7 kB)
# Using cached pip-26.0.1-py3-none-any.whl (1.8 MB)
# ...
#   Attempting uninstall: pip
#     Found existing installation: pip 25.3
#     Uninstalling pip-25.3:
#       Successfully uninstalled pip-25.3
# ...

# %%
import numpy as np
import pandas as pd

from pandas import DataFrame

# %%
numbers_df = DataFrame(np.arange(0, 90, 3).reshape(10, 3), index = ['row 1', 'row 2', 'row 3', 'row 4', 'row 5', 'row 6', 'row 7', 'row 8', 'row 9', 'row 10'], columns = ['col1', 'col2', 'col3'])
columns = ['column 1', 'column 2', 'column 3']

numbers_df
# Out:
#         col1  col2  col3
# row 1      0     3     6
# row 2      9    12    15
# row 3     18    21    24
# row 4     27    30    33
# row 5     36    39    42
# row 6     45    48    51
# row 7     54    57    60
# row 8     63    66    69
# row 9     72    75    78
# row 10    81    84    87

# %%
numbers_df.iloc[0,1]
# Out:
# np.int64(3)

# %%
numbers_df.iloc[0,1] = 20
numbers_df
# Out:
#         col1  col2  col3
# row 1      0    20     6
# row 2      9    12    15
# row 3     18    21    24
# row 4     27    30    33
# row 5     36    39    42
# row 6     45    48    51
# row 7     54    57    60
# row 8     63    66    69
# row 9     72    75    78
# row 10    81    84    87

# %%
numbers_df.iloc[[1,2,4], [1,2]]
# Out:
#        col2  col3
# row 2    12    15
# row 3    21    24
# row 5    39    42

# %% [markdown]
# #### Comparison operators (> < = <= => == !=) and Masking.

# %%
mask = numbers_df > 30
mask
# Out:
#          col1   col2   col3
# row 1   False  False  False
# row 2   False  False  False
# row 3   False  False  False
# row 4   False  False   True
# row 5    True   True   True
# row 6    True   True   True
# row 7    True   True   True
# row 8    True   True   True
# row 9    True   True   True
# row 10   True   True   True

# %%
numbers_df[mask]
# Out:
#         col1  col2  col3
# row 1    NaN   NaN   NaN
# row 2    NaN   NaN   NaN
# row 3    NaN   NaN   NaN
# row 4    NaN   NaN  33.0
# row 5   36.0  39.0  42.0
# row 6   45.0  48.0  51.0
# row 7   54.0  57.0  60.0
# row 8   63.0  66.0  69.0
# row 9   72.0  75.0  78.0
# row 10  81.0  84.0  87.0

# %%
numbers_df[numbers_df > 30] = 0
numbers_df
# Out:
#         col1  col2  col3
# row 1      0    20     6
# row 2      9    12    15
# row 3     18    21    24
# row 4     27    30     0
# row 5      0     0     0
# row 6      0     0     0
# row 7      0     0     0
# row 8      0     0     0
# row 9      0     0     0
# row 10     0     0     0

# %%
numbers_df.iloc[2:6, 1:3]
# Out:
#        col2  col3
# row 3    21    24
# row 4    30     0
# row 5     0     0
# row 6     0     0
